# %%
import torch

# %%
torch.__version__
# Out:
# '1.7.1'

# %%
# !nvidia-smi
# Out:
# Sun Mar 21 18:01:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/lollcat/Autoencoders-deep-dive --branch Pytorch --single-branch Autoencoders-deep-dive
# Out:
# Cloning into 'Autoencoders-deep-dive'...
# remote: Enumerating objects: 223, done.
# remote: Counting objects: 100% (223/223), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 503 (delta 78), reused 191 (delta 57), pack-reused 280
# Receiving objects: 100% (503/503), 86.78 MiB | 53.40 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
import os
os.chdir("Autoencoders-deep-dive")
os.listdir()[0:5]
# Out:
# ['MNIST_ladder',
#  'TF_load_datasets.py',
#  'CIFAR_basic_IAF',
#  'CIFAR_ladder',
#  'Results_and_trained_models']

# %%
# !python TF_load_datasets.py
# Out:
# 2021-03-21 18:27:24.046775: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# ...
# Dl Size...: 100%|███████████████████████████| 102/102 [00:01<00:00, 68.27 MiB/s]
#
# ...
# Generating train examples...:   0%|            | 0/50000 [00:00<?, ? examples/s]2021-03-21 18:27:45.243873: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-21 18:27:45.244828: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-21 18:27:45.620161: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-21 18:27:45.620921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# ...
