# %%
 # set path to parent file
from pathlib import Path
import os
cwd_path = Path.cwd()
set_path = str(cwd_path.parent)
os.chdir(set_path)

# %%
import matplotlib.pyplot as plt
import torch
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
import numpy as np

# %%
"""
import importlib
import IAF_VAE_mnist
importlib.reload(IAF_VAE_mnist)
VAE = IAF_VAE_mnist.VAE.VAE
"""
# Out:
# '\nimport importlib\nimport IAF_VAE_mnist\nimportlib.reload(IAF_VAE_mnist)\nVAE = IAF_VAE_mnist.VAE.VAE\n'

# %%
from IAF_VAE_mnist.VAE import VAE
from Utils.load_4_point import x_train_4_points
data_chunk = torch.tensor(x_train_4_points)

# %% [markdown]
# # IAF

# %%
experiment_dict = {"latent_dim": 2, "n_IAF_steps": 6, "IAF_node_width" : 320}
vae = VAE(**experiment_dict)
# Out:
# running using cpu

# %%
#model_path = "Results_and_trained_models/IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_8__h_dim_200_IAF_node_width_320/2021_03_18-07_47_26_AM/epochs_1001__model"
#model_path = "Results_and_trained_models/IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_8__h_dim_200_IAF_node_width_320/2021_03_18-07_47_26_AM/epochs_2000__model"
model_path = "IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_6__h_dim_200_IAF_node_width_320/2021_03_18-05_34_23_AM/epochs_2000__model"
vae.load_NN_model(model_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-99a8f2e4c1cd> in <module>
#       3 #model_path = "IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_6__h_dim_200_IAF_node_width_320/2021_03_18-05_34_23_AM/epochs_2000__model"
#       4 model_path = "Results_and_trained_models/IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_0__h_dim_200_IAF_node_width_320/2021_03_19-07_19_30_AM/epochs_500__model"
# ----> 5 vae.load_NN_model(model_path)
#
# NameError: name 'vae' is not defined

# %%
fig, ax = plt.subplots(figsize=(5,5))
n_points_latent_vis = 4
cols = mpl.cm.rainbow(np.linspace(0.1, 0.9, n_points_latent_vis))
plt.figure()
for point_n in range(n_points_latent_vis):
    point_repeat = np.zeros((10000, 1, 28, 28))
    point_repeat[:, :, :, :] = data_chunk[point_n, :, :, :]
    encoding_2D = vae.get_latent_encoding(torch.tensor(point_repeat, dtype=torch.float32).to(vae.device))
    ax.scatter(encoding_2D[:, 0], encoding_2D[:, 1], color=cols[point_n], s=2, alpha=0.5)
ax.set_xlabel(r"$z_1$")
ax.set_ylabel(r"$z_2$")
ax.set_ylim((-4, 4))
ax.set_xlim((-4, 4))
ax.set_axisbelow(True)
ax.grid()
print(model_path)
# Out:
# IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_6__h_dim_200_IAF_node_width_320/2021_03_18-05_34_23_AM/epochs_2000__model

# %%
fig, ax = plt.subplots(figsize=(5,5))
n_points_latent_vis = 4
cols = mpl.cm.rainbow(np.linspace(0.1, 0.9, n_points_latent_vis))
plt.figure()
for point_n in range(n_points_latent_vis):
    point_repeat = np.zeros((10000, 1, 28, 28))
    point_repeat[:, :, :, :] = data_chunk[point_n, :, :, :]
    encoding_2D = vae.get_latent_encoding(torch.tensor(point_repeat, dtype=torch.float32).to(vae.device))
    ax.scatter(encoding_2D[:, 0], encoding_2D[:, 1], color=cols[point_n], s=2, alpha=0.5)
ax.set_xlabel(r"$z_1$")
ax.set_ylabel(r"$z_2$")
ax.set_ylim((-4, 4))
ax.set_xlim((-4, 4))
ax.set_axisbelow(True)
ax.grid()
print(model_path)

# %% [markdown]
# # NO IAF

# %%
experiment_dict = {"latent_dim": 2, "n_IAF_steps": 0, "IAF_node_width" : 320}
vae = VAE(**experiment_dict)
epochs = 1000
daddy_path = f"Results_and_trained_models/IAF_VAE_mnist/4_point/no_IAF_4_point/latent_dim_2__n_IAF_steps_0__h_dim_200_IAF_node_width_320/"
time =  "2021_03_18-06_02_46_AM" #"2021_03_18-10_59_27_AM"#
model_path = f"{daddy_path}{time}/epochs_{epochs}__model"
model_path = "Results_and_trained_models/IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_0__h_dim_200_IAF_node_width_320/2021_03_19-07_19_30_AM/epochs_500__model"
vae.load_NN_model(model_path)
# Out:
# running using cpu
# loaded model from Results_and_trained_models/IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_0__h_dim_200_IAF_node_width_320/2021_03_19-07_19_30_AM/epochs_500__model

# %%
fig, ax = plt.subplots(figsize=(5,5))
n_points_latent_vis = 4
cols = mpl.cm.rainbow(np.linspace(0.1, 0.9, n_points_latent_vis))
plt.figure()
for point_n in range(n_points_latent_vis):
    point_repeat = np.zeros((5000, 1, 28, 28))
    point_repeat[:, :, :, :] = data_chunk[point_n, :, :, :]
    encoding_2D = vae.get_latent_encoding(torch.tensor(point_repeat, dtype=torch.float32).to(vae.device))
    ax.scatter(encoding_2D[:, 0], encoding_2D[:, 1], color=cols[point_n], s=2, alpha=0.5)
ax.set_xlabel(r"$z_1$")
ax.set_ylabel(r"$z_2$")
ax.set_ylim((-4, 4))
ax.set_xlim((-4, 4))
ax.set_axisbelow(True)
ax.grid()
fig.savefig("Results_and_trained_models/IAF_VAE_mnist/Final_Figures/no_iaf.png")

# %% [markdown]
# # Prior

# %%
fig, ax = plt.subplots(figsize=(5,5))
prior = np.random.normal(size=(10000, 2))
ax.scatter(prior[:, 0], prior[:, 1], c="black", s=2, alpha=0.2)
ax.set_xlabel(r"$z_1$")
ax.set_ylabel(r"$z_2$")
ax.set_ylim((-4, 4))
ax.set_xlim((-4, 4))
ax.set_axisbelow(True)
ax.grid()

# %% [markdown]
# # Latent space

# %%
experiment_dict = {"latent_dim": 2, "n_IAF_steps": 0, "IAF_node_width" : 400}
vae = VAE(**experiment_dict)
model_path = "Results_and_trained_models/IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_4__h_dim_200_IAF_node_width_400/2021_03_19-07_25_42_AM/epochs_200__model"
vae.load_NN_model(model_path)
# Out:
# running using cpu
# -------------------------------------------------------------------------
# RuntimeError                            Traceback (most recent call last)
# <ipython-input-11-08143f5d002e> in <module>
#       2 vae = VAE(**experiment_dict)
#       3 model_path = "Results_and_trained_models/IAF_VAE_mnist/saved_models/latent_dim_2__n_IAF_steps_4__h_dim_200_IAF_node_width_400/2021_03_19-07_25_42_AM/epochs_200__model"
# ----> 4 vae.load_NN_model(model_path)
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Advanced ML\Assignment\PyTorch\IAF_VAE_mnist\VAE.py in load_NN_model(self, path)
#      51
#      52     def load_NN_model(self, path):
# ---> 53         self.VAE_model.load_state_dict(torch.load(path, map_location=torch.device(self.device)))
#      54         print(f"loaded model from {path}")
#      55
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\nn\modules\module.py in load_state_dict(self, state_dict, strict)
#    1049
#    1050         if len(error_msgs) > 0:
# -> 1051             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1052                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1053         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for VAE_model:
# 	Unexpected key(s) in state_dict: "encoder.IAF_steps.0.FirstLayer.latent_to_layer.weight_g", "encoder.IAF_steps.0.FirstLayer.latent_to_layer.weight_v", "encoder.IAF_steps.0.FirstLayer.latent_to_layer.autoregressive_mask", "encoder.IAF_steps.0.FirstLayer.h_to_layer.bias", "encoder.IAF_steps.0.FirstLayer.h_to_layer.weight_g", "encoder.IAF_steps.0.FirstLayer.h_to_layer.weight_v", "encoder.IAF_steps.0.MiddleLayer.layer_to_layer.bias", "encoder.IAF_steps.0.MiddleLayer.layer_to_layer.weight_g", "encoder.IAF_steps.0.MiddleLayer.layer_to_layer.weight_v", "encoder.IAF_steps.0.MiddleLayer.layer_to_layer.autoregressive_mask", "encoder.IAF_steps.0.FinalLayer.layer_to_m.bias", "encoder.IAF_steps.0.FinalLayer.layer_to_m.weight_g", "encoder.IAF_steps.0.FinalLayer.layer_to_m.weight_v", "encoder.IAF_steps.0.FinalLayer.layer_to_m.autoregressive_mask", "encoder.IAF_steps.0.FinalLayer.layer_to_s.bias", "encoder.IAF_steps.0.FinalLayer.layer_to_s.weight_g", "encoder.IAF_steps.0.FinalLayer.layer_to_s.weight_v", "encoder.IAF_steps.0.FinalLayer.layer_to_s.autoregressive_mask", "encoder.IAF_steps.0.m_SkipLayer.layer_to_layer.autoregressive_mask", "encoder.IAF_steps.0.m_SkipLayer.layer_to_layer.weight_g", "encoder.IAF_steps.0.m_SkipLayer.layer_to_layer.weight_v", "encoder.IAF_steps.0.s_SkipLayer.layer_to_layer.autoregressive_mask", "encoder.IAF_steps.0.s_SkipLayer.layer_to_layer.weight_g", "encoder.IAF_steps.0.s_SkipLayer.layer_to_layer.weight_v", "encoder.IAF_steps.1.FirstLayer.latent_to_layer.weight_g", "encoder.IAF_steps.1.FirstLayer.latent_to_layer.weight_v", "encoder.IAF_steps.1.FirstLayer.latent_to_layer.autoregressive_mask", "encoder.IAF_steps.1.FirstLayer.h_to_layer.bias", "encoder.IAF_steps.1.FirstLayer.h_to_layer.weight_g", "encoder.IAF_steps.1.FirstLayer.h_to_layer.weight_v", "encoder.IAF_steps.1.MiddleLayer.layer_to_layer.bias", "encoder.IAF_steps.1.MiddleLayer.layer_to_layer.weight_g", "encoder.IAF_steps.1.MiddleLayer.layer_to_layer.weight_v", "encoder.IAF_steps.1.MiddleLayer.layer_to_layer.autoregressive_mask", "encoder.IAF_steps.1.FinalLayer.layer_to_m.bias", "encoder.IAF_steps.1.FinalLayer.layer_to_m.weight_g", "encoder.IAF_steps.1.FinalLayer.layer_to_m.weight_v", "encoder.IAF_steps.1.FinalLayer.layer_to_m.autoregressive_mask", "encoder.IAF_steps.1.FinalLayer.layer_to_s.bias", "encoder.IAF_steps.1.FinalLayer.layer_to_s.weight_g", "encoder.IAF_steps.1.FinalLayer.layer_to_s.weight_v", "encoder.IAF_steps.1.FinalLayer.layer_to_s.autoregressive_mask", "encoder.IAF_steps.1.m_SkipLayer.layer_to_layer.autoregressive_mask", "encoder.IAF_steps.1.m_SkipLayer.layer_to_layer.weight_g", "encoder.IAF_steps.1.m_SkipLayer.layer_to_layer.weight_v", "encoder.IAF_steps.1.s_SkipLayer.layer_to_layer.autoregressive_mask", "encoder.IAF_steps.1.s_SkipLayer.layer_to_layer.weight_g", "encoder.IAF_steps.1.s_SkipLayer.layer_to_layer.weight_v", "encoder.IAF_steps.2.FirstLayer.latent_to_layer.weight_g", "encoder.IAF_steps.2.FirstLayer.latent_to_layer.weight_v", "encoder.IAF_steps.2.FirstLayer.latent_to_layer.autoregressive_mask", "encoder.IAF_steps.2.FirstLayer.h_to_layer.bias", "encoder.IAF_steps.2.FirstLayer.h_to_layer.weight_g", "encoder.IAF_steps.2.FirstLayer.h_to_layer.weight_v", "encoder.IAF_steps.2.MiddleLayer.layer_to_layer.bias", "encoder.IAF_steps.2.MiddleLayer.layer_to_layer.weight_g", "encoder.IAF_steps.2.MiddleLayer.layer_to_layer.weight_v", "encoder.IAF_steps.2.MiddleLayer.layer_to_layer.autoregressive_mask", "encoder.IAF_steps.2.FinalLayer.layer_to_m.bias", "encoder.IAF_steps.2.FinalLayer.layer_to_m.weight_g", "encoder.IAF_steps.2.FinalLayer.layer_to_m.weight_v", "encoder.IAF_steps.2.FinalLayer.layer_to_m.autoregressive_mask", "encoder.IAF_steps.2.FinalLayer.layer_to_s.bias", "encoder.IAF_steps.2.FinalLayer.layer_to_s.weight_g", "encoder.IAF_steps.2.FinalLayer.layer_to_s.weight_v", "encoder.IAF_steps.2.FinalLayer.layer_to_s.autoregressive_mask", "encoder.IAF_steps.2.m_SkipLayer.layer_to_layer.autoregressive_mask", "encoder.IAF_steps.2.m_SkipLayer.layer_ ...

# %%
mpl.rcParams['figure.dpi'] = 300
n = 15  # figure with 15x15 digits
half_range = 1
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-half_range, half_range, n)
grid_y = np.linspace(-half_range, half_range, n)
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = np.exp(vae.decoder(z_sample).numpy()[0])
        digit = x_decoded.reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit
plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap="gray")
